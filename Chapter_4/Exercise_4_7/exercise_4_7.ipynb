# %%
import numpy as np
from exercise_4_7 import *

# %%
EXPECTED_NUM_REQ = (3, 4)
EXPECTED_NUM_RET = (3, 2)
DISCOUNT_RATE = 0.9
MAX_NUM_EVAL_ITERATIONS = 1000
POLICY_EVAL_THRESHOLD = 0.000001
MAX_NUM_MOVES = 5
IS_UPDATED_PROBLEM = False

# %%
state_values = np.zeros((21, 21))
deterministic_policy = np.zeros((21, 21), dtype=np.int8)
print("Initiation")
plot_deterministic_policy(deterministic_policy, "$\pi_0$", "pi_0.png")

policy_stable = False
for i in range(10):
    print("Iteration", i)

    state_values = policy_evaluation(state_values, deterministic_policy, EXPECTED_NUM_REQ, EXPECTED_NUM_RET,
        DISCOUNT_RATE, MAX_NUM_EVAL_ITERATIONS, POLICY_EVAL_THRESHOLD, IS_UPDATED_PROBLEM)
    deterministic_policy, policy_stable = policy_improvement(state_values, deterministic_policy,
        EXPECTED_NUM_REQ, EXPECTED_NUM_RET, DISCOUNT_RATE, MAX_NUM_MOVES, POLICY_EVAL_THRESHOLD, IS_UPDATED_PROBLEM)

    print("policy_stable:", policy_stable)
    plot_deterministic_policy(deterministic_policy, f"$\pi_{i + 1}$", f"pi_{i + 1}.png")

    if policy_stable:
        break
# Out:
# Initiation
# Iteration 0
# num eval iterations: 100
# policy_stable: False
# Iteration 1
# num eval iterations: 83
# policy_stable: False
# Iteration 2
# num eval iterations: 76
# policy_stable: False
# Iteration 3
# num eval iterations: 55
# policy_stable: False
# Iteration 4
# num eval iterations: 18
# policy_stable: True
